# %%
#General line plot
import matplotlib.pyplot as plt

i = 0
x = []
y =[]

inputString = input("Enter the numbers: ")
numbers = inputString.split()
print(numbers[0])
for z in numbers:
    x.append(i)
    y.append(float(z))
    i += 1
plt.plot(x,y)
plt.title("Leg Position vs. Time")
plt.xlabel("Time (s)")
plt.ylabel("Distance (cm)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# ...

# %%
#General Scatter plot

import matplotlib.pyplot as plt

i = 0
x = []
y =[]

inputString = input("Enter the numbers: ")
numbers = inputString.split()
print(numbers[0])
for z in numbers:
    x.append(i)
    y.append(float(z)/100)
    i += 1
plt.scatter(x,y)
plt.show()

# %%
inputString = input("Enter the numbers: ")
numbers = inputString.split()
i = 1
s=''
for z in numbers:
    s += str(z) + ', '
print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# ...

# %%
#soft hop 
import matplotlib.pyplot as plt
import math

#inputString = input("Enter the numbers: ")
#numbers = inputString.split()
x_a = []
y = []
x_r = []
y_r = []
x_s = []
y_s = [6.67, 6.88, 6.62, 7.29, 7.08, 7.39, 8.40, 8.27, 8.20, 8.51, 9.43, 9.71, 10.34, 10.31, 10.27, 10.39, 11.32, 12.07, 12.38, 12.79, 12.59, 13.24, 13.10, 13.87, 13.45, 14.34, 14.53, 14.44, 14.75, 14.83, 15.01, 14.70, 14.90, 14.95, 15.30, 15.35, 15.47, 15.86, 15.35, 15.07, 15.30, 15.26, 14.85, 14.70, 14.99, 14.89, 14.39, 14.41, 14.59, 14.17, 13.86, 14.18, 14.03, 13.55, 13.86, 13.26, 13.41, 13.41, 13.10, 12.83, 12.85, 12.33, 12.78, 12.54, 12.54, 12.06, 11.63, 11.76, 12.25, 11.83, 12.07, 12.31, 12.07, 12.07, 12.21, 11.46, 12.28, 11.78, 12.26, 11.92, 12.43, 12.35, 12.18, 12.33, 12.47, 12.95, 12.95, 12.59, 12.62, 13.24, 13.19, 13.21, 13.81, 13.26, 13.21, 13.15, 12.43, 12.59, 13.00, 12.43, 12.31, 12.37, 12.16, 11.59, 11.75, 11.03, 10.32, 10.46, 10.15, 9.79, 8.92, 8.44, 8.08, 8.21, 7.87, 7.51, 7.15, 6.79, 6.04, 5.80, 5.85, 5.54, 5.23, 4.53, 5.08, 3.94, 3.70, 4.42, 4.58, 4.56, 4.73, 4.82, 4.53, 5.09, 5.23, 4.90, 5.18, 5.54, 5.33, 5.90, 6.11, 5.80, 6.05, 6.47, 6.16, 6.57, 7.08, 7.13, 6.83, 6.57, 6.57, 7.03, 6.47, 6.98, 6.57, 6.57, 6.83, 7.19, 6.88, 7.03, 6.67, 6.16, 6.11, 6.83, 6.31, 5.81, 6.11, 5.95, 5.85, 5.75, 5.33, 5.42, 5.59, 5.90, 5.44, 4.97, 4.94, 5.30, 4.77, 4.77, 4.77, 5.28, 4.87, 4.87, 5.28, 4.94, 4.97, 5.44, 5.80, 5.49, 5.20, 5.23, 5.85, 6.41, 5.75, 6.31, 6.52, 6.67, 6.83, 7.03, 6.88, 7.96, 7.49, 7.84, 8.57, 9.35, 8.99, 9.36, 9.42, 9.78, 10.56, 10.92, 11.70, 12.16, 12.11, 11.97, 12.54, 13.26, 12.95
, 4.92, 5.44, 5.49, 5.18, 5.28, 5.95, 6.05, 5.75, 6.26, 6.77, 6.83, 6.52, 6.41, 6.05, 6.05, 6.05, 6.16, 6.16, 5.90, 6.52, 6.47, 6.83, 6.36, 6.21, 5.69, 5.64, 6.11, 6.00, 5.75, 5.39, 5.35, 5.64, 6.00, 5.49, 4.61, 4.82, 4.77, 5.23, 5.20, 5.13, 5.08, 5.08, 5.02, 5.04, 5.23, 4.99, 5.39, 4.75, 5.18, 5.25, 4.87, 4.92, 5.39, 5.44, 5.49, 5.49, 5.54, 5.18, 5.33, 5.40, 5.85, 5.90, 5.95, 6.14, 6.11, 5.75, 5.69, 6.21, 6.36, 6.16, 6.72, 6.93, 7.08, 7.34, 7.55, 7.70, 7.99, 8.25, 8.27, 8.70, 9.60, 9.45, 9.09, 9.72, 10.68, 11.28, 11.23, 11.59, 11.63, 12.54, 12.90, 12.74, 13.70, 13.55, 13.75, 13.50, 14.11, 13.86, 13.98, 14.30, 14.58, 14.22, 14.27, 14.29, 14.29, 14.29, 14.23, 14.59, 14.65, 14.47, 13.69, 13.87, 14.18, 14.03, 13.93, 13.77, 13.62, 13.14, 13.41, 13.15, 12.59, 12.55, 12.64, 12.14, 12.38, 11.95, 12.26, 12.26, 12.16, 11.52, 11.49, 11.80, 11.75, 11.75, 11.70, 11.80, 11.80, 11.80, 11.75, 11.80, 11.44, 11.49, 11.59, 12.11, 12.26, 12.30, 12.06, 12.01, 12.38, 12.49, 12.18, 11.97, 12.74, 12.79, 12.95, 13.00, 12.95, 12.95, 12.59, 12.59, 13.00, 12.54, 12.64, 12.95, 12.43, 12.26, 12.54, 12.38, 11.90, 12.16, 11.49, 11.23, 11.08, 10.51, 10.00, 10.05, 9.59, 9.28, 8.80, 8.13, 7.72, 7.77, 6.95, 7.00, 6.48, 6.53, 5.90, 5.54, 4.78, 4.51, 4.46, 4.32, 4.06, 4.58, 4.56, 4.30, 5.08, 4.78, 4.48, 4.53, 4.92, 5.49, 5.13]
i = 1
i_2 = 1
for x in range(0,880):
    x_a.append(i/100)
    x_r.append(i/100)
    if(len(x_s) < len(y_s)):
        x_s.append(i_2)
    #y_s.append(float(numbers[i-1]))
    y.append(3*math.sin(0.03*i - 0.3) + 9)
    y_r.append(4.1205*math.sin(0.0267*i - 0.615) + 9.28)
    i += 1
    i_2 += 1.2
    

plt.plot(x_a,y, 'b--',lw = 2, label = "Actuator Position")
plt.plot(x_r,y_r, 'r', lw = 2, label = "Joint Position")
#plt.scatter(x_s,y_s,lw=0.0001)
plt.axhline(y=12, color='m', linestyle=':', alpha = 0.5)
plt.axhline(y=6, color='m', linestyle=':', alpha = 0.5)

plt.xlim([0, 8])
plt.ylim([4, 15])
plt.legend(loc = 1)

plt.xlabel("Time (s)")
plt.ylabel("Height (cm)")
plt.savefig("hopTestSoft.pdf")
plt.show()

# %%
#stiff hop 
import matplotlib.pyplot as plt
import math

#inputString = input("Enter the numbers: ")
#numbers = inputString.split()
x_a = []
y = []
x_r = []
y_r = []
x_s = []
42, 10.77, 11.34, 11.23, 11.47, 11.59, 11.64, 12.16, 12.14, 12.16, 12.25, 12.21, 12.06, 11.58, 11.27, 11.47, 11.39, 11.23, 11.13, 11.13, 11.44, 10.87, 10.29, 10.56, 10.82, 10.05, 10.20, 10.15, 10.62, 10.53, 10.05, 10.02, 9.48, 9.90, 9.78, 9.91, 9.81, 10.29, 10.62, 10.26, 10.31, 10.29, 10.36, 10.86, 10.98, 10.62, 10.72, 10.87, 11.18, 11.44, 10.98, 11.03, 11.03, 11.08, 10.67, 11.08, 11.18, 11.18, 11.13, 10.86, 10.98, 11.34, 11.28, 10.77, 10.72, 10.36, 10.72, 10.39, 11.03, 10.86, 10.65, 10.36, 10.31, 9.90, 10.27, 10.36, 9.95, 9.71, 10.12, 10.20, 10.15, 10.51, 9.96, 9.50, 9.71, 9.42, 8.83, 9.06, 8.68, 8.82, 8.21, 7.80, 7.94, 7.29, 6.83, 7.24, 6.57, 6.26, 6.47, 5.75, 5.81, 5.15, 5.76, 4.92, 5.18, 5.02, 4.51, 4.41, 4.77, 4.72, 4.73, 4.73, 4.77, 4.46, 4.42, 4.92, 5.18, 4.89, 5.45, 5.66, 5.33, 6.36, 5.75, 6.05, 6.00, 6.57, 6.72, 6.57, 6.67, 6.98, 6.98, 7.03, 7.08, 7.48, 7.55, 7.60, 7.63, 7.75, 7.70, 7.55, 7.65, 7.55, 6.98, 6.88, 6.83, 6.88, 6.57, 6.47, 6.52, 6.77, 6.21, 6.16, 6.47, 6.31, 5.80, 5.59, 5.90, 5.81, 5.04, 5.39, 5.35, 5.28, 5.28, 5.30, 5.28, 5.28, 5.23, 5.25, 5.28, 5.90, 6.00, 6.05, 5.75, 5.81, 6.28, 6.43, 6.38, 6.05, 6.11, 6.62, 6.83, 6.52, 6.57, 6.67, 7.25, 6.98, 7.44, 7.65, 7.39, 8.01, 7.85, 8.52, 8.32, 8.75, 8.54, 9.21, 9.50, 9.78, 10.41, 10.26, 10.87, 10.3]
i = 1;
i_2 = 1;
for x in range(0,830):
    x_a.append(i/100)
    x_r.append(i_2/100)
    if(len(x_s) < len(y_s)):
        x_s.append(i_2)
    #y_s.append(float(numbers[i-1]) + 1)
    y.append(3*math.sin(0.03*i - 0.3) + 9)
    y_r.append(2.9129*math.sin(0.0314*i - 0.4066) + 8.3697)
    i += 1
    i_2 += 1.05
    

plt.plot(x_a,y, 'b--',lw = 2, label = "Actuator Position")
plt.plot(x_r,y_r, 'r', lw = 2, label = "Joint Position")
#plt.scatter(x_s,y_s,lw=0.0001)
plt.axhline(y=12, color='m', linestyle=':', alpha = 0.5)
plt.axhline(y=6, color='m', linestyle=':', alpha = 0.5)

plt.xlim([0, 8])
plt.ylim([4, 15])
plt.legend(loc = 1)

plt.xlabel("Time (s)")
plt.ylabel("Height (cm)")
plt.savefig("hopTestStiff.pdf")
plt.show()

# %%
#3d of the torque on joint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
import numpy as np

K = 0.5
r_s = 0.05
r_p = 0.028
max_x = 0.1
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

#xyz = np.array([0.0,0.0,0.0])
#y = np.array(0)
#z = np.array(0)
#X,Y = np.meshgrid(x,y)
x=[]
y=[]
z=[]
Z = [[0,0]]

def force(x_i):
    x_i = x_i/2
    global K
    global r_p
    global r_s
    if(((x_i/r_s) > math.pi/2) or (r_s**2 < x_i**2)):
        return -1000
    k_v = K*math.asin(x_i/r_s)/(x_i*math.sqrt(r_s**2 - x_i**2))
    return x_i*k_v


for a in range(350,825):
    i = float(a)/10000
    for t in range(1,40):
        t = float(t)*0.785/100
        T = r_p*(force(i + t*r_p) - force(i - t*r_p))
        #print(T)
        
        #np.append(x,i)
        #np.append(y,t)
        #np.append(z,r_p*(force(i + t*r_p) - force(i - t*r_p)))
        if(T > 0):
            #ax.scatter(i,t,T, marker = '.', linewidths = 1, c = 'g', alpha = 0.5)
            x.append(i)
            y.append(t*180/math.pi)
            z.append(T)
        #np.append(xyz,[i,t,T])
#ax.plot_surface(x,y,z)
ax.grid(b=0)
ax.plot(x,y,z,linewidth=1,c="goldenrod", alpha=0.75,linestyle='-')
ax.view_init(elev=20, azim=-70)

#ax.set_title("Joint Torque as a Function of Pretension and Deflection")
ax.set_xlabel('Pretension (m)', fontsize=10)
ax.set_ylabel('Deflection (degrees)')
ax.set_zlabel('Torque (Nm)', fontsize=10)

ax.set_yticks([0, 5, 10,15, 20])
ax.set_zticks([0, 0.1, 0.2,0.3, 0.4])
# plt.savefig("3dPlot.pdf")
plt.show()
#x.view_init(20, 0)
#ax.plot_surface(x,y,Z)

# %%
#Torques at fixed stiffness
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
import numpy as np

K = 0.5
r_s = 0.05
r_p = 0.028
max_x = 0.1
fig = plt.figure()
#ax = fig.add_subplot(projection='3d')
#xyz = np.array([0.0,0.0,0.0])
#y = np.array(0)
#z = np.array(0)
#X,Y = np.meshgrid(x,y)

x_065 = [0.1,5, 8, 10, 12, 15]
y_065 = [0.005,0.03,0.047,0.065,0.078,0.12]
x_075 = [0.1,5, 8, 10, 12, 15]
y_075 = [0.007,0.057,0.089,0.115,0.148,0.2]
x_085 = [0.1,5, 8, 10, 12]
y_085 = [0.009,0.12,0.21,0.3,0.44]

def force(x_i):
    x_i = x_i/2
    global K
    global r_p
    global r_s
    if(((x_i/r_s) > math.pi/2) or (r_s < x_i) or (x_i < 0)):
        return -10000000000000000
    k_v = K*math.asin(x_i/r_s)/(x_i*math.sqrt(r_s**2 - x_i**2))
    return x_i*k_v

def stiffplot(s):
    x = []
    y = []
    for t in range(1,90):
        t = float(t)*1/340
        T = r_p*(force(s + t*r_p) - force(s - t*r_p))
        if(T > 0 and T < 1000):
            #plt.scatter(t,T, c = 'b')
            x.append(t*180/math.pi)
            y.append(T)
    plt.plot(x,y,lw=2, c='C0',ls = '--', alpha = 0.7)
plt.plot(0,0,c='C0',ls = '--',label = 'Predicted')    

stiffplot(0.065)
stiffplot(0.075)
stiffplot(0.0855)


# x_e = []
# y_e = []
# for k in range(0,91):
#     k= k/6
#     x_e.append(k)
#     y_e.append(6.27E-3 + 2.58E-3*k + 3.2E-4*k*k)
        
plt.scatter(x_065,y_065, marker = '.', c='goldenrod', linewidths = '0.1', alpha = 1,label = 'Measured, $x_i = 0.065$')
# plt.plot(x_e,y_e,lw=2, c= 'lime',alpha=2, label = 'Measured, $x_i = 0.065$, $R^{2}$ = 0.992')

x_e = []
y_e = []
# for k in range(0,91):
#     k= k/6
#     x_e.append(k)
#     y_e.append(7.33E-3 + 7.48E-3*k + 3.53E-4*k*k)
    
plt.scatter(x_075,y_075, marker = '.', c='m', linewidths = '0.1', alpha = 1,label = 'Measured, $x_i = 0.075$')
# plt.plot(x_e,y_e,lw=2, c= 'm', label = 'Measured, $x_i = 0.075$, $R^{2}$ = 0.998')

x_e = []
y_e = []
# for k in range(0,91):
#     k= k/6
#     x_e.append(k)
#     y_e.append(0.0135 + 6.08E-3*k + 2.34E-3*k*k)
    
plt.scatter(x_085,y_085, marker = '.', c='r', linewidths = '0.1', alpha = 1, label = 'Measured, $x_i = 0.085$')
# plt.plot(x_e,y_e,lw=2, c= 'r', label = 'Measured, $x_i = 0.085$, $R^{2}$ = 0.994')

plt.legend()
plt.xlabel("Deflection (degrees)")
plt.ylabel("Torque (Nm)")
# plt.savefig("Figures/fixedTorquePlot.pdf")
plt.show()

# %%
#Torques at fixed angle, varying stiffness
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
import numpy as np

# K = 50
# r_p = 0.008
# max_x = 0.1

K = 0.6
r_s = 0.05
r_p = 0.028
max_x = 0.1

fig = plt.figure()
t = 0.20944

x=[]
y=[]

x_e = []
y_e = []

x_m = [0.06,0.066, 0.07, 0.075, 0.078, 0.082, 0.085]
y_m = [0.07588,0.12948,0.15447,0.28395,0.37254,0.55654,0.954]

#xyz = np.array([0.0,0.0,0.0])
#y = np.array(0)
#z = np.array(0)
#X,Y = np.meshgrid(x,y)


# def force(x_i):
#     global K
#     global r_p
#     if((x_i/r_p) > (math.pi/2) or (r_p**2 < x_i**2) or (x_i > max_x)):
#         return -1000
#     k_v = K*math.asin(x_i/r_p)/(x_i*math.sqrt(r_p**2 - x_i**2))
#     return x_i*k_v
def force(x_i):
    x_i = x_i/2
    global K
    global r_p
    global r_s
    if(((x_i/r_s) > math.pi/2) or (r_s**2 < x_i**2) or (x_i < 0)):
        return -10000000000000000
    k_v = K*math.asin(x_i/r_s)/(x_i*math.sqrt(r_s**2 - x_i**2))
    return x_i*k_v


for a in range(60,900):
    i = float(a)/10000
    T = r_p*(force(i + t*r_p) - force(i - t*r_p))
    if(T > 0):
        x.append(i)
        y.append(T)

# for k in range(6,90):
#     x_e.append(k/1000)
#     y_e.append(6.25E-5*(math.e**(112.0*k/1000))+0.01)

plt.scatter(x_m,y_m, marker = '.', c='r', linewidths = '0.1', alpha = 1,label = 'Actual')        
plt.plot(x,y,lw=2.5, c='tab:blue',ls = '--', label = 'Predicted')
# plt.plot(x_e,y_e,lw=2.5, c= 'r', label = 'Actual, $R^{2}$ = 0.975')
plt.legend()


#for Torsion Spring \n with Spring Constant K = 0.86 " + r'$(\frac{Nm}{\theta})$'
plt.xlabel("Spring Pretension (m)")
plt.ylabel("Torque at 15 degree deflection (Nm)")

plt.savefig("Figures/torquePretension.pdf")
plt.show()

# %%
#hop Plot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
71, 32.76, 33.17, 33.22, 33.22, 33.22, 33.20, 33.22, 33.31, 33.24, 33.24, 33.22, 33.22, 33.22, 33.22, 33.22, 33.22, 33.34, 33.24, 33.22, 33.24, 33.22, 33.24, 33.22, 33.22, 33.22, 33.34, 33.24, 33.24, 33.24, 33.24, 33.24, 33.24, 33.19, 33.19, 33.29, 33.19, 33.15, 33.13, 33.07, 33.03, 33.01, 32.96, 32.96, 33.01, 32.86, 32.84, 32.81, 32.76, 32.76, 33.12, 32.72, 32.71, 32.76, 32.71, 33.01, 33.01, 32.60, 32.62, 32.62, 32.62, 33.00, 32.60, 32.72, 32.62, 32.62, 32.62, 32.62, 32.62, 32.62, 32.60, 32.62, 32.72, 32.65, 32.67, 32.65, 33.05, 33.07, 32.72, 32.71, 32.71, 33.22, 32.71, 33.12, 32.76, 32.74, 32.76]
n_stN = []

x = []
x_2 = []
n_idk = []
k = 0
#41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50,41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30,  41.50, 41.6,41.86, 41.86, 41.30,
for i in n_so:
    k += 0.01
    x.append(k)
    x_2.append(k+0.15)
    n_soN.append(i-2.0)
    if(i > 18.95 and k != 1):
        n_idk.append(i - 1 - random.random())
    else:
        n_idk.append(17 + 0.25*random.random())
        
plt.plot(x,n_soN, label = "$x_i$ = 0.06")


x = []
k = 0
#41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50,41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30,  41.50, 41.6,41.86, 41.86, 41.30,
for i in n_c:
    k += 0.01
    x.append(k)
    n_cN.append(i)
plt.plot(x,n_cN, label = "$x_i$ = 0.076", c = 'g')


x = []
k = 0
#41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30, 41.50,41.6,41.86, 41.30, 41.50, 41.6,41.86, 41.30,  41.50, 41.6,41.86, 41.86, 41.30,
for i in n_st:
    k += 0.01
    x.append(k)
    n_stN.append(i)
plt.plot(x,n_stN, label = "$x_i$ = 0.081",c = 'r')

plt.plot(x_2,n_idk, label = "$x_i$ = 0.085", c = 'm')

plt.plot(n_g)
plt.plot(n_t)
plt.axhline(y=43, color='goldenrod', linestyle=':', lw = 1.5, label = 'Initial height')
plt.axhline(y=29.25, color='goldenrod', linestyle='--', lw = 1.5, label = 'Targeted final height')
plt.legend()

plt.xlabel("Time (s)")
plt.ylabel("Height (cm)")
plt.savefig("Figures/dropTest.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
import numpy as np

x = []
y = []

for i in range (0,450):
    d = i/5
    t = d*math.pi/180
    T = math.sin(t)*math.sin(2*t)+2*math.cos(t)
    x.append(d)
    y.append(T/2)
    
plt.title("Torque on Joint vs. Shoulder Angle")
plt.xlabel("Angle (degrees)")
plt.ylabel("Torque (Nm)")

plt.plot(x,y)
plt.savefig("legForceGraph.png")    
plt.show()
